# %%
import pandas as pd
import jsonlines
import numpy as np
import re

# %%
def rnd(num):
    return round(num * 2) / 2

def get_df(tv_show):
    base_path = "../data"
    speaker_path = f"{base_path}/diarized/{tv_show}.csv"
    transcr_path = f"{base_path}/transcriptions/{tv_show}.jsonl"

    df = pd.read_csv(speaker_path, header=None)
    df.columns = ["start", "end", "speaker"]
    def transform_speaker(speaker_str):
        return int(speaker_str.split("_")[2])
    df["speaker"] = df["speaker"].apply(transform_speaker)

    # round to nearest 0.5 seconds
    max_time = rnd(df.iloc[-1]["end"])

    # create a time series from 0 to max_time
    series = pd.Series(np.arange(0, max_time + 0.5, 0.5))
    series

    new_df = pd.DataFrame()
    new_df["time"] = series

    # DIARIZATION
    # for each speaker, find the time series indices that fall within the speaker's start-end time frame
    df_as_obj = df.to_dict(orient="records")
    for speaker in df_as_obj:
        speaker_id = speaker["speaker"]
        start = rnd(speaker["start"])
        end = rnd(speaker["end"])
        new_df[speaker_id] = new_df["time"].apply(lambda x: 1 if x >= start and x <= end else 0)

    print(df_as_obj[:10])

    # convert from detailed view to a single speaker col, -1 if there's no speaker
    new_df["speaker"] = -1
    for index, row in new_df.iterrows():
        for speaker_id in df["speaker"].unique():
            if row[speaker_id] == 1:
                new_df.at[index, "speaker"] = speaker_id
    new_df = new_df[["time", "speaker"]]

    # TRANSCRIPTIONS
    parsed = []
    with jsonlines.open(transcr_path) as reader:
        for obj in reader:
            timestamp = obj["timestamp"]
            txt = obj["text"]
            start, end = timestamp
            parsed.append({"start": start, "end": end, "text": txt})
    transcript_df = pd.DataFrame(parsed)
    transcript_df["text"] = transcript_df["text"].apply(lambda x: x.strip())
    # replace nan with max_end
    transcript_df["end"] = transcript_df["end"].fillna(max_time)
    # round all times to 0.5
    transcript_df["start"] = transcript_df["start"].apply(lambda x: rnd(x))
    transcript_df["end"] = transcript_df["end"].apply(lambda x: rnd(x))

    pattern = re.compile(r"\d+(?:,\d+)+")
    def filter_start(sent):
        sent = pattern.sub("", sent)
        return re.sub(r"^[^a-zA-Z0-9]+", "", sent)

    transcript_df["text"] = transcript_df["text"].apply(filter_start)

    # expand the start-end to 0.5 second intervals
    for index, row in transcript_df.iterrows():
        start = row["start"]
        end = row["end"]
        text = row["text"]
        for i in np.arange(start, end, 0.5):
            new_df.loc[new_df["time"] == i, "text"] = text
    new_df.fillna("", inplace=True)

    # create a mapping from text -> speaker
    text_to_speaker = {}
    for index, row in new_df.iterrows():
        speaker = row["speaker"]
        text = row["text"]

        if speaker == -1 or text == "":
            continue
        if text not in text_to_speaker:
            text_to_speaker[text] = {}
        if speaker not in text_to_speaker[text]:
            text_to_speaker[text][speaker] = 0
        text_to_speaker[text][speaker] += 1

    text_to_speaker = {k: max(v, key=v.get)
                    for k, v in sorted(text_to_speaker.items(),
                                        key=lambda item: sum(item[1].values()), reverse=True)}

    new_df["speaker"] = new_df["text"].apply(
        lambda x: text_to_speaker[x] if x in text_to_speaker else -1)

    new_df = new_df[new_df["text"] != ""]
    new_df = new_df.drop_duplicates(subset=["text"])
    
    new_df.reset_index(drop=True, inplace=True)
    return new_df

df = get_df("Debatten12okt")
# Out:
# [{'start': 3.9, 'end': 7.0, 'speaker': 5}, {'start': 7.9, 'end': 9.7, 'speaker': 0}, {'start': 10.3, 'end': 11.0, 'speaker': 0}, {'start': 11.6, 'end': 14.2, 'speaker': 0}, {'start': 16.0, 'end': 16.1, 'speaker': 2}, {'start': 17.5, 'end': 25.0, 'speaker': 2}, {'start': 25.6, 'end': 34.9, 'speaker': 5}, {'start': 35.6, 'end': 36.0, 'speaker': 5}, {'start': 36.2, 'end': 38.9, 'speaker': 5}, {'start': 39.1, 'end': 60.0, 'speaker': 5}]

# %%
df.head(50)
# Out:
#      time  speaker                                               text
# 0     4.0       -1          Hei. Denne debatten skal handle om dette.
# 1     7.5       -1  Målet er at flest mulig skal jobbe. Derfor må ...
# 2    16.0       -1                                          Og dette.
# 3    17.5       -1  Det er litt forstemmende at vi ofte får en dis...
# 4    22.0       -1  nivået på ytelser, og altfor lite om hvordan v...
# 5    27.0       -1  Selvfølgelig vet disse to dyrkdrevne politiker...
# 6    30.5       -1  når de sier at flere utenfor arbeid må stå opp...
# 7    33.0       -1  Selvfølgelig kommer reaksjonene fra de som ikk...
# 8    36.5       -1   Men i kveld skal vi ta Vedum og Brenna på ordet.
# 9    39.5       -1  Når de sier at de er så bekymret at over 600 0...
# 10   46.5       -1  Vi skal se på hva slags system de har laget fo...
# 11   51.5       -1  nemlig de uføre, som utgjør om lag 362 500 per...
# 12   56.5       -1  Vi skal spørre hvorfor ikke flere enn 67 000 a...
# 13   63.0       -1                           jobber noe ved siden av.
# 14   65.0       -1  I kveld skal vi undersøke om politikerne har l...
# 15   70.5       -1  eller om vi har det motsatte, et system som st...
# 16   77.0       -1                             Dette er fiktive Lars.
# 17   81.0       -1  Han var i arbeid, men så tok livet en brå vend...
# 18   86.0       -1  og etter hvert kunne han ikke jobbe. Nå er Lar...
# 19   91.0       -1         Uføretrygden hans er på 298 500 kr per år.
# 20   95.0       -1  Så har politikerne bestemt at hvis Lars kan jo...
# 21  101.0       -1  Det første regnestykket trenger du ikke å følg...
# 22  104.5       -1  Jeg skal bare raskt vise hvordan Nav regner ut...
# 23  111.0       -1       Den siste lønnen til Lars var på 487 000 kr.
# 24  116.5       -1  Det gir uføretrygden delt på den tidligere løn...
# 25  124.0       -1          Det gir svaret på hvor mye Lars sin trygd
# 26  126.0       -1                               skal kuttes, med  %.
# 27  129.5       -1  Lars kan tjene opptil 40 % av grunnbeløpet i f...
# 28  137.0       -1      Da Lars ble ufør i 2015, var 1G på 88 370 kr.
# 29  143.5       -1  40 % av 1G blir det 88 370 kr. 40 % av NG 35 0...
# 30  148.5       -1                  Dette er Lars sin inntektsgrense.
# 31  153.0       -1  Grunnen til at vi bruker tall fra 2015, er at ...
# 32  159.0       -1  Dette er det siste de sender ut til sine saksb...
# 33  162.5       -1  Lars melder til Nav at han i 2015 forventer en...
# 34  167.0       -1  på 75 000 kr. Da får vi regnestykket. Inntekte...
# 35  175.0       -1  Dette er altså så mye som Lars i 2015 vil tjen...
# 36  181.5       -1      La oss se hvor mye av dette Lars får beholde.
# 37  185.5       -1      Lars tjente 39 652 kr mer enn inntektsgrensa.
# 38  190.0       -1  Så ganger vi det tallet med kompensasjonsgrad ...
# 39  199.0       -1  Da får vi at Lars får et kutt i uføretrygden p...
# 40  205.0       -1  Den nye uføretrygden til Lars året etter blir ...
# 41  215.5       -1  Det gir 274 000 kr. Så legger vi sammen denne ...
# 42  221.0       -1          med de 75 000 kr han tjente ved siden av.
# 43  224.5       -1  Lars får før skatt vel å merke, får uføretrygd...
# 44  231.5       -1  Lars får uføretrygd og lønn på til sammen 349 ...
# 45  238.5       -1  men beholdt inntekten under 35 3488 kr ville h...
# 46  248.5       -1  Av en inntekt på 75 000 kr sitter Lars igjen m...
# 47  256.5       -1    Med andre ord, det lønner seg for Lars å jobbe,
# 48  260.0       -1  men lønner det seg nok sammenlignet med det Ve...
# 49  281.5       -1                     Velkommen, Tonje Brenna. Takk.

# %%
# Out:
#     time  speaker
# 0    4.0        5
# 1    8.0        0
# 2   10.5        0
# 3   11.5        0
# 4   16.0        2
# 5   17.5        2
# 6   25.5        5
# 7   35.5        5
# 8   36.0        5
# 9   39.0        5
# 10  60.5        5
# 11  64.5        5
# 12  65.5        5
# 13  70.5        5
# 14  74.0        5
# 15  74.5        5
# 16  77.5        5
# 17  81.0        5
# 18  87.5        5
# 19  91.0        5

# %%
tv_show = "Debatten12okt"
base_path = "../data"
speaker_path = f"{base_path}/diarized/{tv_show}.csv"

def rnd(num):
    return round(num * 2) / 2

df = pd.read_csv(speaker_path, header=None)
df.columns = ["start", "end", "speaker"]
# keep only start and speaker. rename start to "time"
df = df[["start", "speaker"]]
df = df.rename(columns={"start": "time"})
df["time"] = df["time"].apply(rnd)

def transform_speaker(speaker_str):
    return int(speaker_str.split("_")[2])

df["speaker"] = df["speaker"].apply(transform_speaker)

# TRANSCRIPTIONS
transcr_path = f"{base_path}/transcriptions/{tv_show}.jsonl"
parsed = []
with jsonlines.open(transcr_path) as reader:
    for obj in reader:
        timestamp = obj["timestamp"]
        txt = obj["text"]
        start, end = timestamp
        parsed.append({"time": rnd(start), "text": txt})

transcript_df = pd.DataFrame(parsed)
transcript_df["text"] = transcript_df["text"].apply(lambda x: x.strip())

pattern = re.compile(r"\d+(?:,\d+)+")
def filter_start(sent):
    sent = pattern.sub("", sent)
    return re.sub(r"^[^a-zA-Z0-9]+", "", sent)

transcript_df["text"] = transcript_df["text"].apply(filter_start)


for index, row in transcript_df.iterrows():
    time = row["time"]
    text = row["text"]
    closest = df.iloc[(df["time"]-time).abs().argsort()[:1]]
    closest_speaker = closest["speaker"].values[0]
    transcript_df.at[index, "speaker"] = closest_speaker
    
    
transcript_df.head(20)
# Out:
#     time                                               text  speaker
# 0    4.0          Hei. Denne debatten skal handle om dette.      5.0
# 1    7.5  Målet er at flest mulig skal jobbe. Derfor må ...      0.0
# 2   16.0                                          Og dette.      2.0
# 3   17.5  Det er litt forstemmende at vi ofte får en dis...      2.0
# 4   22.0  nivået på ytelser, og altfor lite om hvordan v...      5.0
# 5   27.0  Selvfølgelig vet disse to dyrkdrevne politiker...      5.0
# 6   30.5  når de sier at flere utenfor arbeid må stå opp...      5.0
# 7   33.0  Selvfølgelig kommer reaksjonene fra de som ikk...      5.0
# 8   36.5   Men i kveld skal vi ta Vedum og Brenna på ordet.      5.0
# 9   39.5  Når de sier at de er så bekymret at over 600 0...      5.0
# 10  46.5  Vi skal se på hva slags system de har laget fo...      5.0
# 11  51.5  nemlig de uføre, som utgjør om lag 362 500 per...      5.0
# 12  56.5  Vi skal spørre hvorfor ikke flere enn 67 000 a...      5.0
# 13  63.0                           jobber noe ved siden av.      5.0
# 14  65.0  I kveld skal vi undersøke om politikerne har l...      5.0
# 15  70.5  eller om vi har det motsatte, et system som st...      5.0
# 16  77.0                             Dette er fiktive Lars.      5.0
# 17  81.0  Han var i arbeid, men så tok livet en brå vend...      5.0
# 18  86.0  og etter hvert kunne han ikke jobbe. Nå er Lar...      5.0
# 19  91.0         Uføretrygden hans er på 298 500 kr per år.      5.0

# %%
# change the "speaker" to iteratively increase. I.e. start from 1 and increment as we observe new speakers.

# %%
# from the transcript df, find the closest matching speaker
# Out:
#      time                                               text  speaker
# 0     4.0          Hei. Denne debatten skal handle om dette.      5.0
# 1     7.5  Målet er at flest mulig skal jobbe. Derfor må ...      0.0
# 2    16.0                                          Og dette.      2.0
# 3    17.5  Det er litt forstemmende at vi ofte får en dis...      2.0
# 4    22.0  nivået på ytelser, og altfor lite om hvordan v...      5.0
# 5    27.0  Selvfølgelig vet disse to dyrkdrevne politiker...      5.0
# 6    30.5  når de sier at flere utenfor arbeid må stå opp...      5.0
# 7    33.0  Selvfølgelig kommer reaksjonene fra de som ikk...      5.0
# 8    36.5   Men i kveld skal vi ta Vedum og Brenna på ordet.      5.0
# 9    39.5  Når de sier at de er så bekymret at over 600 0...      5.0
# 10   46.5  Vi skal se på hva slags system de har laget fo...      5.0
# 11   51.5  nemlig de uføre, som utgjør om lag 362 500 per...      5.0
# 12   56.5  Vi skal spørre hvorfor ikke flere enn 67 000 a...      5.0
# 13   63.0                           jobber noe ved siden av.      5.0
# 14   65.0  I kveld skal vi undersøke om politikerne har l...      5.0
# 15   70.5  eller om vi har det motsatte, et system som st...      5.0
# 16   77.0                             Dette er fiktive Lars.      5.0
# 17   81.0  Han var i arbeid, men så tok livet en brå vend...      5.0
# 18   86.0  og etter hvert kunne han ikke jobbe. Nå er Lar...      5.0
# 19   91.0         Uføretrygden hans er på 298 500 kr per år.      5.0
# 20   95.0  Så har politikerne bestemt at hvis Lars kan jo...      5.0
# 21  101.0  Det første regnestykket trenger du ikke å følg...      5.0
# 22  104.5  Jeg skal bare raskt vise hvordan Nav regner ut...      5.0
# 23  111.0       Den siste lønnen til Lars var på 487 000 kr.      5.0
# 24  116.5  Det gir uføretrygden delt på den tidligere løn...      5.0
# 25  124.0          Det gir svaret på hvor mye Lars sin trygd      5.0
# 26  126.0                               skal kuttes, med  %.      5.0
# 27  129.5  Lars kan tjene opptil 40 % av grunnbeløpet i f...      5.0
# 28  137.0      Da Lars ble ufør i 2015, var 1G på 88 370 kr.      5.0
# 29  143.5  40 % av 1G blir det 88 370 kr. 40 % av NG 35 0...      5.0
# 30  148.5                  Dette er Lars sin inntektsgrense.      5.0
# 31  153.0  Grunnen til at vi bruker tall fra 2015, er at ...      5.0
# 32  159.0  Dette er det siste de sender ut til sine saksb...      5.0
# 33  162.5  Lars melder til Nav at han i 2015 forventer en...      5.0
# 34  167.0  på 75 000 kr. Da får vi regnestykket. Inntekte...      5.0
# 35  175.0  Dette er altså så mye som Lars i 2015 vil tjen...      5.0
# 36  181.5      La oss se hvor mye av dette Lars får beholde.      5.0
# 37  185.5      Lars tjente 39 652 kr mer enn inntektsgrensa.      5.0
# 38  190.0  Så ganger vi det tallet med kompensasjonsgrad ...      5.0
# 39  199.0  Da får vi at Lars får et kutt i uføretrygden p...      5.0
# 40  205.0  Den nye uføretrygden til Lars året etter blir ...      5.0
# 41  215.5  Det gir 274 000 kr. Så legger vi sammen denne ...      5.0
# 42  221.0          med de 75 000 kr han tjente ved siden av.      5.0
# 43  224.5  Lars får før skatt vel å merke, får uføretrygd...      5.0
# 44  231.5  Lars får uføretrygd og lønn på til sammen 349 ...      5.0
# 45  238.5  men beholdt inntekten under 35 3488 kr ville h...      5.0
# 46  248.5  Av en inntekt på 75 000 kr sitter Lars igjen m...      5.0
# 47  256.5    Med andre ord, det lønner seg for Lars å jobbe,      5.0
# 48  260.0  men lønner det seg nok sammenlignet med det Ve...      5.0
# 49  266.0  Målet er at flest mulig skal jobbe. Derfor må ...      0.0
# 50  273.5  Det er litt forstemmende at vi ofte får en dis...      2.0
# 51  277.5  nivået på ytelser, og altfor lite om hvordan v...      5.0
# 52  281.5                     Velkommen, Tonje Brenna. Takk.      5.0
# 53  284.0  Grunnen til at du er her, er at du leder progr...      5.0
# 54  289.0      Noe av det første du fokuserte på, var dette.      5.0
# 55  293.0  Når du ser dette, du vil at flere skal jobbe. ...      5.0
# 56  300.5  Jeg er opptatt av tre ting. Vi skal sørge for ...      2.0
# 57  305.5  Jeg er opptatt av tre hensyn. Vi trenger hoden...      2.0
# 58  310.5  for å løse store oppgaver. Det er godt for den...      2.0
# 59  315.5  Du har en inntekt, lønn å leve av, kan være ny...      2.0
